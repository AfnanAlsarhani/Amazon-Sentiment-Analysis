# %% [markdown]
# # Sentiment Analysis on Amazon Product Reviews 🛍️
#
# This project performs sentiment analysis using Natural Language Processing (NLP) on sample Amazon reviews.
# Each review is classified as Positive, Neutral, or Negative to uncover customer opinion trends.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-01844acc-26a3-4178-aee0-8936a2c11c22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01844acc-26a3-4178-aee0-8936a2c11c22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Step 1: Load the Dataset
#
# We load a sample of Amazon product reviews containing text and star ratings.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("amazon_reviews_sample.csv")

# Display the first few rows
df.head()
# Out:
#                                               review  rating
# 0  This product is amazing! Totally worth the price.       5
# 1         Terrible quality. It broke after two days.       1
# 2       It’s okay, does the job but nothing special.       3
# 3                Absolutely love it! Will buy again.       5
# 4      Not great, not terrible. Average performance.       3

# %%
# Install TextBlob if not already installed
# !pip install -q textblob

# Import necessary tools
from textblob import TextBlob

# %% [markdown]
# ## Step 2: Sentiment Classification
#
# Using TextBlob, we calculate the polarity of each review and classify it into:
# - **Positive** if polarity > 0.1
# - **Negative** if polarity < -0.1
# - **Neutral** if in between

# %%
# Function to classify sentiment based on polarity score
def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity > 0.1:
        return 'Positive'
    elif polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis to each review
df['sentiment'] = df['review'].apply(get_sentiment)

# Show updated dataset with sentiment
df[['review', 'rating', 'sentiment']]
# Out:
#                                               review  rating sentiment
# 0  This product is amazing! Totally worth the price.       5  Positive
# 1         Terrible quality. It broke after two days.       1  Negative
# 2       It’s okay, does the job but nothing special.       3  Positive
# 3                Absolutely love it! Will buy again.       5  Positive
# 4      Not great, not terrible. Average performance.       3   Neutral
# 5     Fantastic value for money. Highly recommended!       5  Positive
# 6                 Waste of money. Very disappointed.       1  Negative
# 7        Meh... it’s fine, just not what I expected.       3  Positive
# 8             Exceeded my expectations! Great stuff.       5  Positive
# 9          The product arrived late and was damaged.       2  Negative

# %% [markdown]
# ## Step 3: Visualize Sentiment Distribution
#
# We plot a pie chart to show the percentage of positive, neutral, and negative reviews.

# %%
import matplotlib.pyplot as plt

# Count of each sentiment
sentiment_counts = df['sentiment'].value_counts()

# Plot a pie chart
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', colors=['lightgreen', 'gold', 'salmon'])
plt.title('Sentiment Distribution in Amazon Reviews')
plt.show()

# %% [markdown]
# ## Summary & Insights
#
# This project performed sentiment analysis on a sample of Amazon product reviews using the TextBlob library.
#
# **Key Results:**
# - The majority of the reviews were classified as **Positive**.
# - A few reviews were **Negative**, indicating dissatisfaction with the product.
# - Some reviews were **Neutral**, showing mixed or unclear feedback.
#
# **Tools Used:**
# - Pandas for data processing
# - TextBlob for sentiment classification
# - Matplotlib for visualization
#
# This simple NLP project demonstrates how businesses can use sentiment analysis to gauge customer satisfaction and improve products based on review data.
